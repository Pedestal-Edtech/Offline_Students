# %%
i=0
while i>11:
    print(i)

# %% [markdown]
# ## python is created by gudo von ressum.
# used in --
# --web scraping
# --data analyis
# --data science
# --

# %%
a=10
b=25
c=a+b
print("output:",c)
# Out:
# output: 35

# %%
a+=b
c+=b
print(b)
# Out:
# 25

# %%
print(c)
# Out:
# 60

# %%
type(c)
# Out:
# int

# %%
id(c)
# Out:
# 140709947518456

# %%
d="harshit"
e="sharma"
print("Full name:",d+e)
print(type(d+e))
print("Address:",id(d+e))
# Out:
# Full name: harshitsharma
# <class 'str'>
# Address: 2378119545392

# %%
z=10
y=10
id(z)
id(y)
# Out:
# 140709947517656

# %%
a1=3.5
a2=56.8
print("addition:",a1+a2)
print("subtraction:",a1-a2)
print("multiple:",a1*a2)
print("divide;",a1/a2)
# Out:
# addition: 60.3
# subtraction: -53.3
# multiple: 198.79999999999998
# divide; 0.061619718309859156

# %%
b2=input("enter any value")
# Out:
# enter any value 3

# %%
print(type(b2))
# Out:
# <class 'int'>

# %% [markdown]
# ##type casting and code conversion.
# #implicit & explicit.

# %%
c1=input("value")
print(float(c1))
# Out:
# value 3
# 3.0

# %% [markdown]
# <!-- 2 implicit
# 2 explicit
# 2 id fuction
# 2 input fuction  -->

# %% [markdown]
# # 2 impicit
# # 2 explicit
# # 2 id function
# # 2 input function

# %%
c3=int(input("enter value:"))
c4=int(input("enter value two:"))

print(c3+c4)
# Out:
# enter value: 2
# enter value two: 2
# 4

# %%
list2=[1,4,"harshit",54]
list2[0]
# Out:
# 1

# %%
list2[2]
# Out:
# 'harshit'

# %%
list2[-3]
# Out:
# 4

# %%
list2[-1]
# Out:
# 54

# %% [markdown]
# # 5 List questions on indexing.

# %%
print(dir(list2))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list2.append("harshit")
print(list2)
# Out:
# [1, 4, 54, 'harshit', 'harshit', 'harshit', 'harshit']

# %%
list3=[45,67,434,"Harshit","sharma"]
print(type(list3))
# Out:
# <class 'list'>

# %%
print(dir(tuple))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
list3.append("suhana")
print(list3)
# Out:
# [45, 67, 434, 'Harshit', 'sharma', 'suhana']

# %%
list3.count(45)
# count is used to calculate the number of values in list.
# Out:
# 1

# %%
list2.count("harshit")
# Out:
# 3

# %%
tuple1=("harshit",45,56.767)

# %%
print(tuple1)
# Out:
# ('harshit', 45, 56.767)

# %%
tuple1[0][1]
# Out:
# 'a'

# %%
tuple1[0][3]
# Out:
# 's'

# %%
list5=[44,6455,223,4341,786,32]
list5.sort()
print(list5)
# Out:
# [32, 44, 223, 786, 4341, 6455]

# %%
list5.pop(1)
# Out:
# 223

# %%
print(len(list3))
# Out:
# 6

# %%
print(list3)
# Out:
# [45, 67, 434, 'Harshit', 'sharma', 'suhana']

# %%
list5.reverse()
print(list5)
# Out:
# [6455, 4341, 786, 32]

# %%
list5.insert(2,44)

# %%
print(list5)
# Out:
# [6455, 4341, 44, 786, 32]

# %%
list5.reverse()
print(list5)
# Out:
# [6455, 4341, 44, 786, 32]

# %%
del list5[3]

# %%
print(list5)
# Out:
# [6455, 4341, 44, 32]

# %%
def harshit():
    print("harshit Sharma")
harshit()
# Out:
# harshit Sharma

# %%
list5.pop(3)
# Out:
# 32

# %%
print(list5)
list5.append(5656)
# Out:
# [6455, 4341, 5656]

# %%
print(list5)
# Out:
# [6455, 4341, 5656, 5656]

# %%
list5.pop(3)
# Out:
# 5656

# %%
print(list5)
# Out:
# [6455, 4341, 5656]

# %%
print(dir(list5))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list5.clear()

# %%
print(list5)
# Out:
# []

# %%
list5.append(12)
list5.append(12343)
list5.append(123434)
list5.append(123456)

# %%
print(list5)
# Out:
# [12, 12, 12343, 123434, 123456, 12, 12343, 123434, 123456]

# %%
list5.sort()
print(list5)
# Out:
# [12, 12, 12, 12343, 12343, 123434, 123434, 123456, 123456]

# %%
del list5[2]
print(list5)
# Out:
# [12, 12, 12343, 12343, 123434, 123434, 123456, 123456]

# %%
list5[3]=334

# %%
print(list5)
# Out:
# [12, 12, 12343, 334, 123434, 123434, 123456, 123456]

# %%
list5.extend([1,2])
print(list5)
# Out:
# [12, 12, 12343, 334, 123434, 123434, 123456, 123456, 1, 2, 1, 2]

# %%
list5.sort()
