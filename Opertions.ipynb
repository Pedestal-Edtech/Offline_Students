# %%
y=input("enter").split(' ')
# Out:
# enter harshit

# %%
print(y)
# Out:
# ['harshit']

# %%
type(y)
# Out:
# list

# %%
y.append("Sharma")

# %%
print(y)
# Out:
# ['harshit', 'Sharma']

# %%
y.insert(1,"suhana")

# %%
print(y)
# Out:
# ['harshit', 'suhana', 'Sharma']

# %%
from collections import namedtuple
i=int(input("enter"))
tr=input().split()
score=namedtuple("score".ts)
total=0
for i in range(n):
    r-score(*input().split())
    total+=float(r.MARKS)
print(total/n)
# Out:
# enter harshit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 from collections import namedtuple
# ----> 2 i=int(input("enter"))
#       3 tr=input().split()
#       4 score=namedtuple("score".ts)
#
# ValueError: invalid literal for int() with base 10: 'harshit'
