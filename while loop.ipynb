# %%
i=1
while i<=10:
    if (i==5):
        break
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # Print even numbers

# %%
i=1
while i<=10:
    if(i%2==0):
     print(i)
    i=i+1
# Out:
# 1
# 3
# 5
# 7
# 9
