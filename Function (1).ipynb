# %%
def harshit():
    a=int(input("enter the value one:"))
    b=int(input("enter the value second:"))
    c=a+b
    print(c)
    d=a/b
    e=a-b
    f=a*b
    print(d)
    print(e)
    print(f)
harshit()
# Out:
# enter the value one: 2
# enter the value second: 3
# 5
# 0.6666666666666666
# -1
# 6

# %%
def listing():
    list1=[12,23,34,45]
    a1=int(input("enter any values:"))
    list1.append(a1)
    print(list1)
    list1.sort()
    print("After Sorting:",list1)
listing()
# Out:
# enter any values: 56
# [12, 23, 34, 45, 56]
# After Sorting: [12, 23, 34, 45, 56]

# %%
tp=(12,23,4,5452,12)
print(tp)
# Out:
#   Cell In[11], line 1
#     print(dir(tuple())
#                       ^
# SyntaxError: incomplete input

# %%
def list2():
    list2=[12,34,545,56,54]
    print(list2)
    a2=int(input("enter value to find:"))
    for i in range(len(list2)):
        if list2[i]==a2:
            print("value is matches at",i,"index.")
            break;
        else: 
            print("not matched")
list2()
# Out:
# [12, 34, 545, 56, 54]
# enter value to find: 33
# not matched
# not matched
# not matched
# not matched
# not matched

# %%
def ls3():
    list4=[1,5,3,6,9,3,56]
    print

# %%
year=1990
def is_leap(year):
    if year%400:
        pass;
    elif year%100:
        print("false")
    elif year%4:
        print("false")
    return is_leap
print(is_leap(year))
# Out:
# <function is_leap at 0x0000024EB547EAC0>

# %%
def calculator(a4,b4):
    return a4+b4
result=calculator(5,4)
print("output:",result)

def subtraction(a5,b5):
    return a5+b5
res_sub=subtraction(4,7)
print("sub_output",res_sub)

def multiply(a6,b6):
    return a6+b6
res_mult=multiply(4,6)
print("multiplier:",res_mult)

def divide(a7,b7):
    return a7+b7
res_divide=divide(3,9)
print("result of divide:",res_divide)
# Out:
# output: 9
# sub_output 11
# multiplier: 10
# result of divide: 12

# %%
def calc(opertor):
    a8=int(input("enter the first value :"))
    b8=int(input("enter the second value:"))
    op=input("enter any opertor from (+,-,*,/):")       
    match opertor:
         case '+':
             c8=a8+b8
             print(c8)
         case '-':
             c8=a8-b8
             print(c8)
         case '*':
             c8=a8*b8
             print(c8)
         case '/':
             c8=a8/b8
             print(c8)
print(type(calc('*')))
# Out:
# enter the first value : 3
# enter the second value: 6
# enter any opertor from(+,-,*,/): *
# 18
# <class 'NoneType'>

# %%
def calc(opertor):
    a8=int(input("enter the first value :"))
    b8=int(input("enter the second value:"))
    op=input("enter any opertor from(+,-,*,/):")
           
    match opertor:
         case '+':
             return a8+b8
         case '-':
             return a8-b8
         case '*':
             return a8*b8
         case '/':
             return a8/b8


print(type(calc('op')))
# Out:
# enter the first value : 2
# enter the second value: 2
# enter any opertor from(+,-,*,/): *
# <class 'NoneType'>

# %%
x=1
y=1
z=2
n=3
ls=[[i, j, k]]
for i in range(x + 1):
    for j in range(y + 1):
        for k in range(z + 1):
           if i + j + k != n:
                print([x+y+z])
