# %%
ls=float(input("enter the list element"))
print(ls)
print(type(ls))

# %%
def abc(x,y):
    print(x+y)
    return x,y
i= abc(2,4)
print(type(i))
# Out:
# 6
# <class 'tuple'>

# %%
print(i)
# Out:
# (2, 4)

# %%
def rahul():
    print("rahul saini")
rahul()

# %%
j=float(10)
print(j)
# Out:
# 10.0

# %%
type(j)
# Out:
# float

# %%
k=5
type(float(k))
# Out:
# float

# %%
l=input("enter the value")
j1=float(l)
print(type(j))
# Out:
# enter the value 2.2
# <class 'float'>

# %%
id(j1)
# Out:
# 1875894245520

# %%
ls=[1,2,3,5]
ls.index(1)
# Out:
# 0

# %%
ls.append(4)
ls.append(8)
ls.append(6)
ls.append(7)
ls.append(9)

# %%
print(ls)
# Out:
# [1, 2, 3, 5, 4, 8, 6, 7, 9]

# %%
ls.count(4)
# Out:
# 1

# %%
print(dir(ls))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(ls)
ls.remove(5)
print(ls)
# Out:
# [1, 2, 3, 5, 4, 8, 6, 7, 9]
# [1, 2, 3, 4, 8, 6, 7, 9]

# %%
ls.remove(9)
print(ls)
# Out:
# [1, 2, 3, 4, 8, 6, 7]

# %%
ls.remove(8)
print(ls)
# Out:
# [1, 2, 3, 4, 6, 7]

# %%
ls.append(5)
print(ls)
# Out:
# [1, 2, 3, 4, 6, 7, 5]

# %%
ls.append(8)
print(ls)
# Out:
# [1, 2, 3, 4, 6, 7, 5, 8]

# %%
ls.sort()
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
print(ls)
print(ls[-1])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# 8

# %%
ls.insert(-2,112)
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 112, 7, 8]

# %%
ls.insert(19,15)
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 112, 7, 8, 15]

# %%
ls.pop()
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 112, 7, 8]

# %%
ls.count(10)
# Out:
# 0

# %%
print(len(ls))
# Out:
# 9

# %%
ls.insert(20,15)
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 112, 7, 8, 15]

# %%
print(len(ls))
# Out:
# 10

# %%
ls.insert(20,16)
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 112, 7, 8, 15, 16]

# %%
ls.sort()
print(ls)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 15, 16, 112]

# %%
ls.reverse()
print(ls)
# Out:
# [112, 16, 15, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
print(ls)
# Out:
# [112, 16, 15, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
print(ls(8))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(ls(8))
#
# TypeError: 'list' object is not callable

# %%
ls[6]
# Out:
# 5

# %%
#implist
a=input("enter the elemet")
print(a)
type (a)
# Out:
# enter the elemet 5
# 5
# str

# %%
#explist
b=int(input("enter the element"))
print(b)
type(b)
# Out:
# enter the element 6
# 6
# int

# %%
a=22
b=3
c=a+b
d=a-b
e=a*b
f=a//b
print("addition",c)
print("substraction",d)
print("multiply",e)
print("divide",f)
# Out:
# addition 25
# substraction 19
# multiply 66
# divide 7

# %%
y=int(input("enter the year"))
if y/4==0:
    print("it is leap year")
elif y/100!=0:
    print("it is leap not year")
elif y/400==0:
    print("leap year")
else:
 print("non leap year")
# Out:
# enter the year 1990
# it is leap not year

# %%
def fun(year):
 year=input("enter the year")
leap=year
if year/4==0:
elif year/100!=0:
elif year/400==0:
 return(true):
fun()
# Out:
#   Cell In[4], line 5
#     elif year/100!=0:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
ls=[]
ls.insert(0,5)
ls.insert(1,10)
ls.insert(0,6)
print(ls)
ls.remove(6)
ls.append(9)
ls.append(1)
ls.sort()
print(ls)
ls.pop()
ls.reverse()
print(ls)
# Out:
# [6, 5, 10]
# [1, 5, 9, 10]
# [9, 5, 1]

# %%
class first:
    x=50
obj=first()
print(obj.x)
# Out:
# 50

# %%
a='hello'
#ls=['hello']
#ls.append(a)
for i in range(len(a)):
    print(a(i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       2 #ls=['hello']
#       3 #ls.append(a)
#       4 for i in range(len(a)):
# ----> 5     print(a(i))
#
# TypeError: 'str' object is not callable

# %%
word = "hello"
print(char(woord))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 word = "hello"
# ----> 2 print(char(woord))
#
# NameError: name 'char' is not defined
