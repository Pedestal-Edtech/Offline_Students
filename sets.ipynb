# %%
s={1,2,3,4}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
print(s1|s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
print(s1&s2)
# Out:
# {4, 5}

# %%
thisset={"apple","banana","cherry",True,1,2,4,5}
print(thisset)
# Out:
# {'cherry', True, 2, 4, 5, 'banana', 'apple'}

# %%
s3={"abc",50,True,10,"xyz",False}
print(s3)
print(type(s3))
# Out:
# {False, True, 50, 'abc', 10, 'xyz'}
# <class 'set'>

# %%
print(len(thisset))
# Out:
# 7

# %%
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
a=set(("applle",'banana','cat'))
print(a)
# Out:
# {'banana', 'cat', 'applle'}

# %%
s3={"abc",50,True,10,"xyz",False}
s3.pop()
print(s3)
# Out:
# {True, 50, 'abc', 10, 'xyz'}

# %%
s3={"abc",50,True,10,"xyz",False}
for i in s3:
    print(i)
# Out:
# False
# True
# 50
# abc
# 10
# xyz

# %%
print(50 in s3)
# Out:
# True

# %%
print('a' in s3)
# Out:
# False

# %%
s3.add(20)
print(s3)
# Out:
# {False, True, 50, 20, 'abc', 10, 'xyz'}

# %%
s3.add('ab')
print(s3)
# Out:
# {False, True, 50, 20, 'abc', 'ab', 10, 'xyz'}

# %%
s3.update(a)
print(s3)
# Out:
# {False, True, 'banana', 'ab', 10, 'xyz', 50, 20, 'applle', 'abc', 'cat'}

# %%
ls=['dog','fan']
a.update(ls)
print(a)
# Out:
# {'banana', 'fan', 'applle', 'dog', 'cat'}

# %%
a.remove('banana')
print(a)
# Out:
# {'fan', 'applle', 'dog', 'cat'}

# %%
print(a.pop())
print(a)
# Out:
# fan
# {'applle', 'dog', 'cat'}

# %%
a.clear()
print(a)
# Out:
# set()

# %%
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 del a
# ----> 2 print(a)
#
# NameError: name 'a' is not defined

# %%
for i in s3:
    print(i)
# Out:
# False
# True
# banana
# ab
# 10
# xyz
# 50
# 20
# applle
# abc
# cat

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
s3={"abc",50,True,10,"xyz",False}
print(s1.union(s2,s3))
# Out:
# {False, 1, 2, 3, 4, 5, 6, 7, 10, 'xyz', 50, 'abc'}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
print(s1.intersection(s2))
# Out:
# {4, 5}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
s3={"abc",50,True,10,"xyz",False}
print(s1.intersection(s2,s3))
# Out:
# set()

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
s3={"abc",50,True,10,"xyz",False}
print(s1.difference(s2,s3))
# Out:
# {2, 3}

# %%
s1={1,2,3,4,5}
s2={4,5,6,7}
s3={"abc",50,True,10,"xyz",False}
print(s1.symmetric_difference(s2))
# Out:
# {1, 2, 3, 6, 7}

# %%
set1=set()
n=int(input("enter the set len"))
for i in range(n):
    e=input("enter the set element")
    set1.add(e)
print(set1)
# Out:
# enter the set len 2
# enter the set element rahul
# enter the set element rahulsharma
# {'rahul', 'rahulsharma'}
