# %%
# 08/06/2026 
#  if else 
a=int(input("enter value1"))
b=float(input("enter value2"))
sum=a+b
c=type(a)
d=type(b)

if c==str or d==str:
    a=int(a)
    b =int(b)
    
    print("output=",a+b)
else:
     print("not integer")
# Out:
# enter value1 10
# enter value2 20
# output= 30.0

# %%
str="21.0"
float(str)
# Out:
# 21.0
