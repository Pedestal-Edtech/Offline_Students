# %%
# List
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
#append or add the elements
list=["rajesh","4th year",2027,"rajasthan"]
list.append("mehta")
print(list)
# Out:
# ['rajesh', '4th year', 2027, 'rajasthan', 'mehta']

# %%
# copy
list2=["rajesh kumar",2023,"sikar",40]
list2.copy()
# Out:
# ['rajesh kumar', 2023, 'sikar', 40]

# %%
# count, use to count the same values
list2.count("rajesh kumar")
# Out:
# 1

# %%
# reverse
list2.reverse()
print(list2)
# Out:
# [40, 'sikar', 2023, 'rajesh kumar']

# %%
# extend
list2.extend("rajesh kumar")
print(list2)
# Out:
# [40, 'sikar', 2023, 'rajesh kumar', '2', '0', '2', '3', 'r', 'a', 'j', 'e', 's', 'h', ' ', 'k', 'u', 'm', 'a', 'r', 'r', 'a', 'j', 'e', 's', 'h', ' ', 'k', 'u', 'm', 'a', 'r']

# %%
# remove
list2.remove("2")
print(list2)
# Out:
# [40, 'sikar', '0', '2', '3', 'r', 'a', 'j', 'e', 's', 'h', ' ', 'k', 'u', 'm', 'a', 'r', 'r', 'a', 'j', 'e', 's', 'h', ' ', 'k', 'u', 'm', 'a', 'r']

# %%
# index 
list3=["jaipur",2004,8,7]
list3.index("jaipur")
# list3.index(8)
# Out:
# 0

# %%
print(list3)
# list3.sort()
# print(list3)
# Out:
# ['jaipur', 2004, 8, 7]

# %%
list3.pop()
print(list3)
# Out:
# ['jaipur', 2004, 8]

# %%
list3.insert(1,"as")
list3.insert(2,"kumar")
print(list3)
# Out:
# ['jaipur', 'as', 'kumar', 'behror', 'kumar', 'behror', 2004, 8]

# %%
list3.clear()
print(list3)
# Out:
# []

# %%
list4=[20,35,25,56,21,40]
list4.sort()
print(list4)
# Out:
# [20, 21, 25, 35, 40, 56]

# %%
del list4[4]
print(list4)
# Out:
# [20, 21, 25, 35, 56]

# %%
# update
list4[4] = 58
print(list4)
# Out:
# [20, 21, 25, 35, 58]

# %%
l5=[10,20,30,40,50]
char = 30
for i in range(len(l5)):
    if (l5[i]==char):
        print("yes")
    else:
        print("element not found")
# Out:
# element not found
# element not found
# yes
# element not found
# element not found

# %%
l5=[10,20,30,40,50]
char = 10
for i in range(len(l5)):
    if (l5[i]==char):
        print("yes")
        break;
    else:
     print("element not found")
# Out:
# yes

# %%
l5=[10,20,30,40,50]
char=int(input("enter any number"))
for i in range(len(l5)):
    if (l5[i]==char):
        print("matched:",l5[i])
        break;
    else:
        print("element not found")
# Out:
# enter any number 20
# element not found
# matched: 20

# %%
l6=["HARSHIT","SHARMA","RAJESH","MEHTA"]
print(l6[1:3])
# Out:
# ['SHARMA', 'RAJESH']

# %%
a=l6[1:3]
print(type(a))
a.index("SHARMA")
print(a)
# Out:
# <class 'list'>
# ['SHARMA', 'RAJESH']

# %%
# to check address of list elements 
l7=[1,2,3,4]
print(id(l7[0]))
# Out:
# 140711605810088

# %%
list10=[20,80,60,40]
list10.sort()
print(list10)
# Out:
# [20, 40, 60, 80]

# %%
list10.insert(0,50)
print(list10)
# Out:
# [50, 20, 40, 60, 80]

# %%
list10.sort()
print(list10)
# Out:
# [20, 40, 50, 60, 80]

# %%
if __name__ == '__main__':
    N = int(input())
    list=[]
    list.insert(0,5)
    list.insert(1,10)
    list.insert(0,6)
    print(list)
    list.remove(6)
    list.append(9)
    list.append(1)
    list.sort()
    print(list)
    list.pop()
    list.reverse()
    list.count("list")
    print(list)
# Out:
#  12
# [6, 5, 10]
# [1, 5, 9, 10]
# [9, 5, 1]
