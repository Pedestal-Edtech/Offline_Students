# %%
d={"key" : "value", "name":"rahul", "name":"rahul","course": "data science","age": 20}
print(d)
# Out:
# {'key': 'value', 'name': 'rahul', 'course': 'data science', 'age': 20}

# %%
d1={"topics": ("dict","sets")}
print(d1)
# Out:
# {'topics': ('dict', 'sets')}

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
d["name"]="RAHUL"
d["topic"]="python"
print(d)
# Out:
# {'key': 'value', 'name': 'RAHUL', 'course': 'data science', 'age': 20, 'topic': 'python'}

# %%
s1={1,2,3,4}
s2={4,5,6}
print(type(s1))
# Out:
# <class 'set'>

# %%
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
print(s1|s2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(s1&s2)
# Out:
# {4}

# %%
print(s1-s2)
# Out:
# {1, 2, 3}

# %%
print(s1^s2)
# Out:
# {1, 2, 3, 5, 6}

# %%
dic={"name":"rahul","course": "data science" ,"address": "sikar"}
print(dic)
# Out:
# {'name': 'rahul', 'course': 'data science', 'address': 'sikar'}

# %%
dic["address"]
# Out:
# 'sikar'

# %%
dic["address"]= "palwas sikar"
print(dic)
# Out:
# {'name': 'rahul', 'course': 'data science', 'address': 'palwas sikar'}

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
dic.copy ()
print(dic)
# Out:
# {'name': 'rahul', 'course': 'data science', 'address': 'palwas sikar'}

# %%
dic.fromkeys('1')
# Out:
# {'1': None}

# %%
dic.keys()
# Out:
# dict_keys(['name', 'course', 'address'])

# %%
dic.pop("course")
print(dic)
# Out:
# {'name': 'rahul', 'address': 'palwas sikar'}

# %%
dic.popitem()
print(dic)
# Out:
# {'name': 'rahul'}

# %%
dic.update({"age":20})
print(dic)
# Out:
# {'name': 'rahul', 'age': 20}

# %%
dic.items()
# Out:
# dict_items([('name', 'rahul'), ('age', 20)])

# %%
dic.values()
#print(dic)
# Out:
# dict_values(['rahul', 20])

# %%
dic.get("name")
# Out:
# 'rahul'

# %%
dc1={}
key=input("enter the key")
dc3=dc2.fromkeys(key)
print(dc3)
for i in dc3.keys():
    j= input("enter the values",[i])
    dc3[i]=j
print(dc3)
# Out:
# enter the key 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 dc1={}
#       2 key=input("enter the key")
# ----> 3 dc3=dc2.fromkeys(key)
#       4 print(dc3)
#       5 for i in dc3.keys():
#
# NameError: name 'dc2' is not defined

# %%
dict1={}
n=int(input("enter the number of key"))
for i in range(n):
    key=input("enter the key")
    value=input("enter the values")
    dict1.update({key:value})
print(dict1)
# Out:
# enter the number of key 2
# enter the key name
# enter the values rahul
# enter the key course
# enter the values data science
# {'name': 'rahul', 'course': 'data science'}

# %%
print("harshit ","sharma",sep=",")
# Out:
# harshit ,sharma

# %%
a=int,input("enter the value").split(' ')
print(a)
# Out:
# enter the value harshit
# (<class 'int'>, ['harshit'])

# %%
a="harshit"
a.fromkeys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 a="harshit"
# ----> 2 a.fromkeys()
#
# AttributeError: 'str' object has no attribute 'fromkeys'
